# %%
import pandas as pd
import numpy as np

# %%
Location = "datasets/Kickstartercombo.csv"
df = pd.read_csv(Location)
df.head()
# Out:
#    Unnamed: 0          ID                                               name  \
# 0           0  1000002330                    The Songs of Adelaide & Abullah
# 1           1  1000004038                                     Where is Hank?
# 2           2  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 3           3  1000011046  Community Film Project: The Art of Neighborhoo...
# 4           4  1000014025                               Monarch Espresso Bar
#
#   main_category        category country       state     goal  pledged  \
# 0    Publishing          Poetry      GB      failed   1000.0      0.0
# 1  Film & Video  Narrative Film      US      failed  45000.0    220.0
# 2         Music           Music      US      failed   5000.0      1.0
# 3  Film & Video    Film & Video      US    canceled  19500.0   1283.0
# 4          Food     Restaurants      US  successful  50000.0  52375.0
#
#   currency             launched             deadline  backers  usd pledged  \
# ...

# %%
dupe = df.duplicated()
df[dupe]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, ID, name, main_category, category, country, state, goal, pledged, currency, launched, deadline, backers, usd pledged, usd_goal_real, usd_pledged_real]
# Index: []

# %%
df.isnull().sum()
# Out:
# Unnamed: 0               0
# ID                       0
# name                     8
# main_category            0
# category                 0
# country                  0
# state                    0
# goal                     0
# pledged                  0
# currency                 0
# launched                 0
# deadline                 0
# backers                  0
# usd pledged           7594
# usd_goal_real       323750
# usd_pledged_real    323750
# dtype: int64

# %%
df2=df[['main_category','usd pledged','country','launched','deadline','state','goal','backers']]
df2
# Out:
#        main_category   usd pledged country             launched  \
# 0         Publishing      0.000000      GB  2015-08-11 12:12:00
# 1       Film & Video    220.000000      US  2013-01-12 00:20:00
# 2              Music      1.000000      US  2012-03-17 03:24:00
# 3       Film & Video   1283.000000      US  2015-07-04 08:35:00
# 4               Food  52375.000000      US  2016-02-26 13:38:00
# 5               Food   1205.000000      US  2014-12-01 18:30:00
# 6               Food    453.000000      US  2016-02-01 20:05:00
# 7             Design   8233.000000      US  2014-04-24 18:14:00
# 8       Film & Video   6240.570000      US  2014-07-11 21:55:00
# 9         Publishing      0.000000      CA  2013-09-09 18:19:00
# 10             Music  12700.000000      US  2013-03-09 06:42:00
# 11            Crafts      0.000000      US  2014-09-02 17:11:00
# 12             Games      0.000000      US  2016-02-09 23:01:00
# 13            Design    664.000000      US  2015-01-29 02:10:00
# ...

# %%
df1=df.groupby(['main_category','usd pledged','country','goal','state'])['backers'].mean()
df1
# Out:
# main_category  usd pledged   country  goal       state
# Art            0.00000       AT       900.0      failed           2.000000
#                                       1000.0     failed           1.000000
#                                       1500.0     failed           1.000000
#                                       1700.0     live             0.000000
#                                       2000.0     canceled         0.333333
#                                                  failed           0.000000
#                                       2500.0     failed          18.000000
#                                       4750.0     failed           1.000000
#                                       5000.0     failed           0.666667
#                                       5055.0     failed          29.000000
#                                       7000.0     failed           0.000000
#                                       9000.0     failed           0.000000
# ...

# %%
df2=df2.dropna()

# %%
df2.isnull().sum()
# Out:
# main_category    0
# usd pledged      0
# country          0
# launched         0
# deadline         0
# state            0
# goal             0
# backers          0
# dtype: int64

# %%
df2.to_csv('Kickstartercombo.csv',index=True,header=True)

# %%
df2.corr()
# Out:
#              usd pledged      goal   backers
# usd pledged     1.000000  0.005871  0.705763
# goal            0.005871  1.000000  0.004405
# backers         0.705763  0.004405  1.000000
