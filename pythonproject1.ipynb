# %%
#import libraries
import pandas as pd
import numpy as np

# %%
location = "datasets/DC_Properties.csv"
df = pd.read_csv(location)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (18,19,20,21,22,23,24,33,34,35,37,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 0                0       4          0      Warm Cool  Y        2.0      8
# 1                1       3          1      Warm Cool  Y        2.0     11
# 2                2       3          1  Hot Water Rad  Y        2.0      9
# 3                3       3          1  Hot Water Rad  Y        2.0      8
# 4                4       2          1      Warm Cool  Y        1.0     11
# 5                5       3          2  Hot Water Rad  Y        1.0     10
# 6                6       1          0      Warm Cool  Y        2.0      5
# 7                7       3          1  Hot Water Rad  Y        2.0      8
# 8                8       3          1      Warm Cool  Y        2.0      7
# 9                9       1          1  Hot Water Rad  Y        1.0      6
# 10              10       3          0     Forced Air  N        3.0     12
# 11              11       5          0  Hot Water Rad  Y        3.0     16
# ...

# %%
#show the column names in the dataset
df.columns
#or print(df.columns)
# Out:
# Index(['Unnamed: 0', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS',
#        'BEDRM', 'AYB', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE',
#        'QUALIFIED', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE',
#        'CNDTN', 'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES',
#        'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM',
#        'LIVING_GBA', 'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID',
#        'LATITUDE', 'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD',
#        'CENSUS_TRACT', 'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
df[['BATHRM','QUADRANT','ROOMS','PRICE']]#to compare factors that change the price
# Out:
#         BATHRM QUADRANT  ROOMS      PRICE
# 0            4       NW      8  1095000.0
# 1            3       NW     11        NaN
# 2            3       NW      9  2100000.0
# 3            3       NW      8  1602000.0
# 4            2       NW     11        NaN
# 5            3       NW     10  1950000.0
# 6            1       NW      5        NaN
# 7            3       NW      8  1050000.0
# 8            3       NW      7  1430000.0
# 9            1       NW      6        NaN
# 10           3       NW     12        NaN
# 11           5       NW     16        NaN
# 12           2       NW      9        NaN
# 13           2       NW     11        NaN
# 14           3       NW      5  1325000.0
# 15           2       NW      9        NaN
# 16           3       NW      8  1240000.0
# 17           2       NW      6        NaN
# 18           3       NW     10        NaN
# 19           3       NW      9   592250.0
# 20           3       NW     14    33232.0
# ...

# %%
df44=df9[df9['PRICE'].notnull()&df9['QUADRANT'].notnull()]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-20b1d326283f> in <module>()
# ----> 1 df44=df9[df9['PRICE'].notnull()&df9['QUADRANT'].notnull()]
#
# NameError: name 'df9' is not defined

# %%
df9=df[['ASSESSMENT_NBHD','YR_RMDL','CNDTN','ROOMS','QUADRANT','PRICE']] #to compare factors that change the price 
df9

# %%
dupe = df.duplicated() #creates list of True/False values
df[dupe] #shows rows where duplicated is True

# %%
#drops duplicate rows, default is to keep first observation
df.drop_duplicates()

# %%
df = pd.read_csv("datasets/DC_Properties.csv")
df.head()#missing data

# %%
#drop rows with any missing data
df_no_missing = df.dropna()
df_no_missing

# %%
df.groupby('QUADRANT')['PRICE'].mean()

# %%
df2=df.groupby('QUADRANT')['PRICE'].max()
df2

# %%
df3=df.groupby('QUADRANT')['PRICE'].min()
df3

# %%
df4=df.groupby('QUADRANT')['ROOMS'].count()
df4

# %%
df5=df.groupby('ASSESSMENT_NBHD')['PRICE'].min()#price assesment depending on the neighborhood
df5

# %%
#df['ASSESSMENT_NBHD'].max()
df

# %%
df55=df.groupby('ASSESSMENT_NBHD')['PRICE'].max()
df55

# %%
df99=df.groupby(['ASSESSMENT_NBHD','YR_RMDL','CNDTN','ROOMS','QUADRANT'])['PRICE'].max()
df99 ####from this we can come to conclude that the house price is dependence on re modeled year 
#quadrant tells us the houses in NW are older and with less price 
#missing price that would make our assesment harder in  NW 
#houses in NE are more expensive we can concluse is threyeare of remodel in the twenty's
# Out:
# ASSESSMENT_NBHD      YR_RMDL  CNDTN      ROOMS  QUADRANT
# 16th Street Heights  1920.0   Average    8      NW               NaN
#                      1923.0   Average    6      NW               NaN
#                                          9      NW               NaN
#                      1925.0   Average    7      NW               NaN
#                      1931.0   Average    9      NW               NaN
#                      1933.0   Average    9      NW               NaN
#                      1950.0   Average    9      NW               NaN
#                      1952.0   Average    11     NW               NaN
#                      1956.0   Average    7      NW               NaN
#                      1959.0   Average    6      NW               NaN
#                      1960.0   Average    7      NW               NaN
#                      1962.0   Average    9      NW               NaN
#                      1963.0   Average    4      NW               NaN
# ...

# %%
df5=df.groupby('QUADRANT')['PRICE'].max()
df
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 0                0       4          0      Warm Cool  Y        2.0      8
# 1                1       3          1      Warm Cool  Y        2.0     11
# 2                2       3          1  Hot Water Rad  Y        2.0      9
# 3                3       3          1  Hot Water Rad  Y        2.0      8
# 4                4       2          1      Warm Cool  Y        1.0     11
# 5                5       3          2  Hot Water Rad  Y        1.0     10
# 6                6       1          0      Warm Cool  Y        2.0      5
# 7                7       3          1  Hot Water Rad  Y        2.0      8
# 8                8       3          1      Warm Cool  Y        2.0      7
# 9                9       1          1  Hot Water Rad  Y        1.0      6
# 10              10       3          0     Forced Air  N        3.0     12
# 11              11       5          0  Hot Water Rad  Y        3.0     16
# ...

# %%
df[['BATHRM','QUADRANT','ROOMS','PRICE']]
# Out:
#         BATHRM QUADRANT  ROOMS      PRICE
# 0            4       NW      8  1095000.0
# 1            3       NW     11        NaN
# 2            3       NW      9  2100000.0
# 3            3       NW      8  1602000.0
# 4            2       NW     11        NaN
# 5            3       NW     10  1950000.0
# 6            1       NW      5        NaN
# 7            3       NW      8  1050000.0
# 8            3       NW      7  1430000.0
# 9            1       NW      6        NaN
# 10           3       NW     12        NaN
# 11           5       NW     16        NaN
# 12           2       NW      9        NaN
# 13           2       NW     11        NaN
# 14           3       NW      5  1325000.0
# 15           2       NW      9        NaN
# 16           3       NW      8  1240000.0
# 17           2       NW      6        NaN
# 18           3       NW     10        NaN
# 19           3       NW      9   592250.0
# 20           3       NW     14    33232.0
# ...

# %%
df.sort_values('QUADRANT') #default is ascending=True
#does not change structure of df
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 79359        79359       3          0     Forced Air  Y        1.0      6
# 83469        83469       1          0      Warm Cool  Y        1.0      7
# 83468        83468       1          0      Warm Cool  Y        1.0      7
# 83467        83467       1          0  Hot Water Rad  N        1.0      7
# 83466        83466       1          0      Warm Cool  Y        1.0      7
# 83465        83465       1          0      Warm Cool  Y        1.0      7
# 83464        83464       1          1     Forced Air  Y        1.0      6
# 83463        83463       1          0      Warm Cool  Y        1.0      7
# 83462        83462       1          0      Warm Cool  Y        1.0      7
# 83461        83461       1          1      Warm Cool  Y        1.0      7
# 83460        83460       1          1      Warm Cool  Y        1.0      7
# 83459        83459       1          0      Warm Cool  Y        1.0      7
# ...

# %%
df.describe()
# Out:
#           Unnamed: 0         BATHRM      HF_BATHRM      NUM_UNITS  \
# count  158957.000000  158957.000000  158957.000000  106696.000000
# mean    79478.000000       1.810678       0.458237       1.198039
# std     45887.077707       0.976396       0.587571       0.596924
# min         0.000000       0.000000       0.000000       0.000000
# 25%     39739.000000       1.000000       0.000000       1.000000
# 50%     79478.000000       2.000000       0.000000       1.000000
# 75%    119217.000000       2.000000       1.000000       1.000000
# max    158956.000000      14.000000      11.000000       6.000000
#
#                ROOMS          BEDRM            AYB       YR_RMDL  \
# count  158957.000000  158957.000000  158686.000000  80928.000000
# mean        6.187736       2.732506    1941.987579   1998.243537
# std         2.618165       1.358864      33.640234     16.575786
# min         0.000000       0.000000    1754.000000     20.000000
# ...

# %%
df_no_missing = df.dropna()
df_no_missing
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, BATHRM, HF_BATHRM, HEAT, AC, NUM_UNITS, ROOMS, BEDRM, AYB, YR_RMDL, EYB, STORIES, SALEDATE, PRICE, QUALIFIED, SALE_NUM, GBA, BLDG_NUM, STYLE, STRUCT, GRADE, CNDTN, EXTWALL, ROOF, INTWALL, KITCHENS, FIREPLACES, USECODE, LANDAREA, GIS_LAST_MOD_DTTM, SOURCE, CMPLX_NUM, LIVING_GBA, FULLADDRESS, CITY, STATE, ZIPCODE, NATIONALGRID, LATITUDE, LONGITUDE, ASSESSMENT_NBHD, ASSESSMENT_SUBNBHD, CENSUS_TRACT, CENSUS_BLOCK, WARD, SQUARE, X, Y, QUADRANT]
# Index: []
#
# [0 rows x 49 columns]

# %%
df[['ROOMS','PRICE']]
# Out:
#         ROOMS      PRICE
# 0           8  1095000.0
# 1          11        NaN
# 2           9  2100000.0
# 3           8  1602000.0
# 4          11        NaN
# 5          10  1950000.0
# 6           5        NaN
# 7           8  1050000.0
# 8           7  1430000.0
# 9           6        NaN
# 10         12        NaN
# 11         16        NaN
# 12          9        NaN
# 13         11        NaN
# 14          5  1325000.0
# 15          9        NaN
# 16          8  1240000.0
# 17          6        NaN
# 18         10        NaN
# 19          9   592250.0
# 20         14    33232.0
# 21         12        NaN
# 22          6   907400.0
# 23          5  1065000.0
# 24          8  1100000.0
# 25          8    20000.0
# 26         10        NaN
# 27          9   703700.0
# 28         10        NaN
# 29         11  1210000.0
# ...       ...        ...
# 158927      6        NaN
# 158928      5   632400.0
# 158929      5   574000.0
# 158930      4   365000.0
# 158931      4   405000.0
# ...
